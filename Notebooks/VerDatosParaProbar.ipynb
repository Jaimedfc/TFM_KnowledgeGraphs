# %%
import numpy as np
import pandas as pd
from ampligraph.utils import restore_model
from sklearn import metrics
from xgboost import XGBClassifier

df = pd.read_pickle("../Data/reducedDataset001.pkl")

df["data_id"] = df.index.values.astype(str)
df["data_id"] = "Dato" + df.data_id
df["subject_id"] = df.Sujeto.values.astype(str)
df["train"] = df.Sujeto > "S14"

# %%
df[~df["train"]].head()
# Out:
#                ECG       EMG       EDA       TEMP      RESP Sujeto  label  \
# 5913351  -0.076035 -0.001785  3.011703  34.154999 -3.651428    S14      3
# 22013102 -0.133347 -0.002884  6.579971  34.586395  9.931946    S11      2
# 26963397 -0.040970 -0.007645  2.823257  33.585327 -3.453064    S14      1
# 12955353 -0.197800 -0.018265  2.003098  35.396637 -3.216553    S10      2
# 19233301  0.070175  0.011124  0.750351  34.353546 -3.411865    S10      1
#
#                data_id subject_id  train
# 5913351    Dato5913351        S14  False
# 22013102  Dato22013102        S11  False
# 26963397  Dato26963397        S14  False
# 12955353  Dato12955353        S10  False
# 19233301  Dato19233301        S10  False
